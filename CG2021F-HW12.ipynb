# %% [markdown]
# # CG2021F-HW12 🤣

# %% [markdown]
# ### 下載 HW12 📡

# %%
# 下載 hw12
# !git clone https://github.com/NTUT-CG-Lab/cg2021f-hw12.git
# Out:
# Cloning into 'cg2021f-hw12'...
# remote: Enumerating objects: 1114, done.
# remote: Counting objects: 100% (1114/1114), done.
# remote: Compressing objects: 100% (1020/1020), done.
# remote: Total 1114 (delta 82), reused 1111 (delta 82), pack-reused 0
# Receiving objects: 100% (1114/1114), 35.70 MiB | 22.80 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %% [markdown]
# ### 下載模型 💾

# %%
# 下載模型 
# !gdown --id 1_sSWgH9UbNyOHzFiUjOS7mC5n1XAxCNn

# 解壓縮檔案
# !unzip model.zip

# 複製模型至hw12資料夾下
# !cp -r model cg2021f-hw12
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_sSWgH9UbNyOHzFiUjOS7mC5n1XAxCNn
# To: /content/model.zip
# 100% 757M/757M [00:08<00:00, 88.0MB/s]
# Archive:  model.zip
#    creating: model/
#   inflating: model/model.pth
#    creating: model/vit_checkpoint/
#    creating: model/vit_checkpoint/imagenet21k/
#   inflating: model/vit_checkpoint/imagenet21k/R50+ViT-B_16.npz

# %% [markdown]
# ### 安裝環境 🔨

# %%
# %cd cg2021f-hw12
# Out:
# /content/cg2021f-hw12

# %%
# !pip install torch===1.4.0 torchvision===0.5.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 753.4 MB 6.7 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 63.2 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 132 kB 13.9 MB/s
# ...
#      |████████████████████████████████| 145 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 68.4 MB/s
# ...
#      |████████████████████████████████| 88 kB 9.5 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 56.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 636 kB 66.4 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 76 kB 6.5 MB/s
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.6
# ...

# %% [markdown]
# ### 進入 hw12 資料夾 ⏩

# %%
# %cd cg2021f-hw12
# Out:
# /content/cg2021f-hw12

# %% [markdown]
# ### 影像分割 ⚡

# %%
# !python predict.py
# Out:
# Load model ...
# Predict ...
# 100% 290/290 [00:20<00:00, 14.20it/s]

# %% [markdown]
# ### 輸出nrrd檔 🧊

# %%
# TODO write_nrrd.py 
# !python write_nrrd.py

# %% [markdown]
# ### 壓縮輸出資料 📦

# %%
# 壓縮輸出資料
# !zip -r /content/data.zip data
# Out:
#   adding: data/ (stored 0%)
#   adding: data/pred_data/ (stored 0%)
#   adding: data/pred_data/masks/ (stored 0%)
#   adding: data/pred_data/masks/ID00423637202312137826377/ (stored 0%)
#   adding: data/pred_data/masks/ID00423637202312137826377/245.jpg (deflated 55%)
#   adding: data/pred_data/masks/ID00423637202312137826377/11.jpg (deflated 55%)
#   adding: data/pred_data/masks/ID00423637202312137826377/194.jpg (deflated 23%)
#   adding: data/pred_data/masks/ID00423637202312137826377/160.jpg (deflated 23%)
#   adding: data/pred_data/masks/ID00423637202312137826377/153.jpg (deflated 25%)
#   adding: data/pred_data/masks/ID00423637202312137826377/63.jpg (deflated 36%)
#   adding: data/pred_data/masks/ID00423637202312137826377/97.jpg (deflated 46%)
#   adding: data/pred_data/masks/ID00423637202312137826377/121.jpg (deflated 45%)
#   adding: data/pred_data/masks/ID00423637202312137826377/155.jpg (deflated 23%)
# ...
